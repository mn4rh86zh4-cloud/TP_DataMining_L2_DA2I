# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# 1. CSV
df_csv = pd.read_csv("../data/student_performance.csv")

# 2. API
api_response = requests.get("https://jsonplaceholder.typicode.com/posts")
df_api = pd.DataFrame(api_response.json())

# 3. Web Scraping
url = "https://www.bbc.com/news"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
titles = [h2.text for h2 in soup.find_all("h2")]
df_web = pd.DataFrame(titles, columns=["titre"])

# 4. دمج البيانات (مثال على concat)
df_final = pd.concat([df_csv, df_api.head(len(df_csv)), df_web.head(len(df_csv))], axis=1)

print(df_final.head())
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
#
#    class_participation  total_score grade  userId   id  \
# 0                  3.8         97.9     A     1.0  1.0
# 1                  2.5         83.9     B     1.0  2.0
# 2                  5.3        100.0     A     1.0  3.0
# 3                  7.0        100.0     A     1.0  4.0
# 4                  6.9         92.0     A     1.0  5.0
#
#                                                title  \
# 0  sunt aut facere repellat provident occaecati e...
# 1                                       qui est esse
# 2  ea molestias quasi exercitationem repellat qui...
# 3                               eum et est occaecati
# 4                                 nesciunt quas odio
#
#                                                 body  \
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...
#
#                                                titre
# 0  US temporarily eases Russia oil sanctions as I...
# 1  US frees up Russian oil as Iran war drives ene...
# 2  The US may move some of its anti-missile syste...
# 3  KPop Demon Hunters to return as Netflix announ...
# 4  US refuelling plane crashes in Iraq, military ...
